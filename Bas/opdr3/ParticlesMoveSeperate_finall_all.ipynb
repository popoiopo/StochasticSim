# %%
import scipy.optimize as so
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.linalg as la
from IPython.display import IFrame, display, HTML, Markdown
import random
import math
import seaborn as sns


def prettyfie(ax, x, y, title, legendYN='Yes'):

    # Remove borders
    ax.spines['top'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['left'].set_visible(False)
    ax.grid(alpha=0.25)

    # Remove unnecessary ticks
    ax.tick_params(
        axis='both',
        which='both',
        bottom=False,
        top=False,
        labelbottom=True,
        left=False,
        right=False,
        labelleft=True)

    if legendYN == 'Yes':
        # Create legend and grid
        ax.legend(framealpha=1, shadow=True)
        ax.legend()

    # Set labels and title
    ax.set_xlabel(x, fontsize=14)
    ax.set_ylabel(y, fontsize=14)
    ax.set_title(title, fontsize=14)
    ax.tick_params(axis='both', which='major', labelsize=12)


def printmd(string):
    display(Markdown(string))

# %%
def log_progress(sequence, every=None, size=None, name='Items'):
    from ipywidgets import IntProgress, HTML, VBox
    from IPython.display import display

    is_iterator = False
    if size is None:
        try:
            size = len(sequence)
        except TypeError:
            is_iterator = True
    if size is not None:
        if every is None:
            if size <= 200:
                every = 1
            else:
                every = int(size / 200)  # every 0.5%
    else:
        assert every is not None, 'sequence is iterator, set every'

    if is_iterator:
        progress = IntProgress(min=0, max=1, value=1)
        progress.bar_style = 'info'
    else:
        progress = IntProgress(min=0, max=size, value=0)
    label = HTML()
    box = VBox(children=[label, progress])
    display(box)

    index = 0
    try:
        for index, record in enumerate(sequence, 1):
            if index == 1 or index % every == 0:
                if is_iterator:
                    label.value = '{name}: {index} / ?'.format(
                        name=name, index=index)
                else:
                    progress.value = index
                    label.value = u'{name}: {index} / {size}'.format(
                        name=name, index=index, size=size)
            yield record
    except:
        progress.bar_style = 'danger'
        raise
    else:
        progress.bar_style = 'success'
        progress.value = index
        label.value = "{name}: {index}".format(
            name=name, index=str(index or '?'))

# %%
def plot(coordList):
    plt.rcParams['figure.figsize'] = [10, 10]
    sns.set()
    sns.set_style("dark")
    fig = plt.figure()
    ax = plt.subplot(111)
    colors = list(range(len(coordList)))
    ax.scatter(coordList[:, 0], coordList[:, 1], c=colors, cmap='Dark2')
    circle1 = plt.Circle((0, 0), radius, alpha=0.2, color="olive")
    ax.add_artist(circle1)
    plotpretify(
        ax,
        1.1,
        minx=-1.1,
        miny=-1.1,
        maxy=1.1,
        Grid=False,
        LL=False,
        LB=False)


def highlight_min(s):
    '''
    highlight the maximum in a Series yellow.
    '''
    is_min = s == s.min()
    return ['background-color: #b3fcd0' if v else '' for v in is_min]


def getScheme_data(iters, plot="No", scheme="Sigmoid", markovChain=1):

    answer = []

    if scheme == "Sigmoid":
        linspace = np.linspace(0, 7, iters)
        for x in linspace:
            answer.append(0.5 +
                          math.erf((math.sqrt(math.pi) / 2) * (x - 2)) * -0.5)
    elif scheme == "Exp":
        for x in range(iters):
            answer.append(np.exp(-x / (iters / 10)))
    elif scheme == "Expvar":
        for x in range(iters):
            answer.append(
                max(
                    np.exp(-x / iters) - ((1.5 * x) / iters) * (1 / math.e),
                    0))
    elif scheme == "Expvar2":
        for x in range(iters):
            answer.append(max(np.exp(-x / iters) - 1.1 * (1 / math.e), 0))
    elif scheme == "Hillclimb":
        for x in range(iters):
            answer.append(0)
    elif scheme == "Binary":
        for x in range(iters):
            if x < iters / 2:
                answer.append(1)
            else:
                answer.append(0)
    elif scheme == "Linear":
        for x in range(iters):
            answer.append(1 - (x / iters))

    if plot == "Yes":
        plotanswer = np.repeat(answer, markovChain)
        fig, ax = plt.subplots(1, 1, figsize=(5, 3))
        ax.plot(plotanswer, label="Acceptance chance")
        ax.legend()
        prettyfie(ax, "iteration", "Acceptance", scheme, legendYN="Yes")
        plt.show()
    return np.array(answer)


def incircle(crds, r=1):
    return np.power(crds[0], 2) + np.power(crds[1], 2) < r


def spawn(r=1):
    x = random.uniform(-r, r)
    limits = [-np.sqrt(r**2 - x**2), np.sqrt(r**2 - x**2)]
    y = random.uniform(limits[0], limits[1])
    return [x, y]


# Good score when somewhere < 2
def checkScore(coord):
    totalDist = 0
    for i in range(len(coord)):
        for j in range(i, len(coord)):
            if i != j:
                totalDist += 1 / abs(
                    math.hypot(coord[j][0] - coord[i][0],
                               coord[j][1] - coord[i][1]))
    return totalDist


def move(k, coord, temp, rate):
    F = np.array([0.0, 0.0])
    velocity = np.zeros(2, float)
    for l in coord:
        if any(l != k):
            r = np.array(k) - np.array(l)
            F1 = (r / (np.linalg.norm(r)**3) * rate)
            F += F1
    newPoint = k + F
    xr = random.uniform(-1, 1) * (1 / 50)
    yr = random.uniform(-1, 1) * (1 / 50)
    newPoint += [xr, yr]
    if not incircle(newPoint, radius):
        newPoint = newPoint / la.norm(newPoint)
    return newPoint, F


def submove(k, i, coord, temp, rate, score):
    global coordListList
    cT, favo = move(k, coord, temp, rate)
    coordTemp = np.copy(coord)
    coordTemp[i] = cT
    coordListList.append(coordTemp)
    scoreTemp = checkScore(coordTemp)
    if temp > 0:
        chance = np.exp(-(scoreTemp - score) / temp)
    else:
        chance = 0
    if score > scoreTemp:
        return np.array(coordTemp), favo
    elif chance > random.random():
        return np.array(coordTemp), favo
    else:
        return coord, favo


def changeCoordSingle(coord, temp, rate):
    score = checkScore(coord)
    fav = []
    for i, k in enumerate(coord):
        coord, favo = submove(k, i, coord, temp, rate, score)
        fav.append(favo)
    return coord


def changeCoordAll(coord, temp, rate):
    counter = 0
    score = checkScore(coord)
    while counter < 10:
        fav = []
        coordTemp = []
        for i, k in enumerate(coord):
            cT, favo = move(k, coord, temp, rate)
            coordTemp.append(cT)
            fav.append(favo)
        scoreTemp = checkScore(coordTemp)
        if temp > 0:
            chance = np.exp(-(scoreTemp - score) / temp)
        else:
            chance = 0
        if score > scoreTemp:
            return np.array(coordTemp)
        elif chance > random.random():
            return np.array(coordTemp)
    return coord


def start_sim(coordList,
              radius,
              pointsNum,
              iterations,
              rate,
              scheme,
              markovChain,
              moveScheme,
              plotScheme="No"):
    #     global coordListList
    schemeData = np.repeat(
        getScheme_data(
            math.ceil(iterations / markovChain),
            plot=plotScheme,
            scheme=scheme), markovChain)

    #     coordListList = []
    #     coordListList.append(coordList)
    checklist = []
    for i in range(iterations):
        temp = schemeData[i]
        coordList = moveScheme(coordList, temp, rate)
        #         coordListList.append(coordList)
        checklist.append(checkScore(coordList))

    return checklist


coordListList = []

radius = 1
pointsNums = list(range(11, 31))
iterations = 100
rate = math.pow(10, -4)
schemes = ["Hillclimb", "Sigmoid", "Exp", "Expvar", "Binary", "Linear"]
# checks = []
# coordListListList = []
results = {}
mcl = [1, 10, 100]
moveScheme = changeCoordAll

data = []
rowcount = 0
for i, scheme in enumerate(schemes):
    printmd(f"### scheme: {scheme}")
    for j, markovL in enumerate(mcl):
        data.append([])
        printmd(f"### Markovlength: {markovL}")
#         getScheme_data(
#             math.ceil(iterations / markovL),
#             plot="Yes",
#             scheme=scheme,
#             markovChain=markovL)
        for pointsNum in log_progress(
                pointsNums, every=1, size=len(pointsNums), name='Items'):
            random.seed(147)
            coordList = []
            for i in range(pointsNum):
                coordList.append(spawn(radius))
            coordList = np.array(coordList)
            #             printmd(f"## Number of points: {pointsNum}")
            checklist = start_sim(
                coordList,
                radius,
                pointsNum,
                iterations,
                rate,
                scheme,
                markovL,
                moveScheme,
                plotScheme="No")
            data[rowcount].append(checklist[-1])
        rowcount += 1

schemas = ["Mean"]
mcls = [""]
for i, scheme in enumerate(schemes):
    for ml in mcl:
        schemas.append(scheme)
        mcls.append(ml)
arrays = [schemas, mcls]

tuples = list(zip(*arrays))
data.insert(0, [0 for i in range(len(data[0]))])

index = pd.MultiIndex.from_tuples(tuples, names=['Scheme', 'MarkovLength'])
s = pd.DataFrame(data, index=index, columns=pointsNums)
meanRow = [np.mean(s[i][1:]) for i in pointsNums]
p = s - meanRow
for i in pointsNums:
    p[i][0] = abs(p[i][0])
    
p.to_pickle("finalPickleAll.pkl") 
final =  p.round(3).T.style.apply(highlight_min, axis=1)
display(final)
writer = pd.ExcelWriter('finalrun_All.xlsx')
final.to_excel(writer,'Sheet1')
writer.save()
# Out:
# ### scheme: Hillclimb
# ### Markovlength: 1
# VBox(children=(HTML(value=''), IntProgress(value=0, max=20)))
# ### Markovlength: 10
# VBox(children=(HTML(value=''), IntProgress(value=0, max=20)))
# ### Markovlength: 100
# VBox(children=(HTML(value=''), IntProgress(value=0, max=20)))
# ### scheme: Sigmoid
# ### Markovlength: 1
# VBox(children=(HTML(value=''), IntProgress(value=0, max=20)))
# ### Markovlength: 10
# VBox(children=(HTML(value=''), IntProgress(value=0, max=20)))
# ### Markovlength: 100
# VBox(children=(HTML(value=''), IntProgress(value=0, max=20)))
# ### scheme: Exp
# ### Markovlength: 1
# VBox(children=(HTML(value=''), IntProgress(value=0, max=20)))
# ### Markovlength: 10
# VBox(children=(HTML(value=''), IntProgress(value=0, max=20)))
# ### Markovlength: 100
# VBox(children=(HTML(value=''), IntProgress(value=0, max=20)))
# ### scheme: Expvar
# ### Markovlength: 1
# VBox(children=(HTML(value=''), IntProgress(value=0, max=20)))
# ### Markovlength: 10
# VBox(children=(HTML(value=''), IntProgress(value=0, max=20)))
# ### Markovlength: 100
# VBox(children=(HTML(value=''), IntProgress(value=0, max=20)))
# ### scheme: Binary
# ### Markovlength: 1
# VBox(children=(HTML(value=''), IntProgress(value=0, max=20)))
# ### Markovlength: 10
# VBox(children=(HTML(value=''), IntProgress(value=0, max=20)))
# ### Markovlength: 100
# VBox(children=(HTML(value=''), IntProgress(value=0, max=20)))
# ### scheme: Linear
# ### Markovlength: 1
# VBox(children=(HTML(value=''), IntProgress(value=0, max=20)))
# ### Markovlength: 10
# VBox(children=(HTML(value=''), IntProgress(value=0, max=20)))
# ### Markovlength: 100
# VBox(children=(HTML(value=''), IntProgress(value=0, max=20)))
# <style  type="text/css" >
#     #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow0_col1 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow0_col2 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow0_col3 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow1_col1 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow1_col2 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow1_col3 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow2_col7 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow3_col13 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow3_col14 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow4_col4 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow5_col1 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow5_col2 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow5_col3 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow6_col7 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow6_col8 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow7_col7 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow8_col7 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow9_col8 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow10_col4 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow11_col7 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow11_col8 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow12_col5 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow13_col7 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow14_col1 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow14_col2 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow14_col3 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow15_col1 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow15_col2 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow15_col3 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow15_col7 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow16_col1 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow16_col2 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow16_col3 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow16_col7 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow16_col8 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow17_col1 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow17_col2 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow17_col3 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow18_col1 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow18_col2 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow18_col3 {
#             background-color:  #b3fcd0;
#         }    #T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow19_col10 {
#             background-color:  #b3fcd0;
#         }</style>
# <table id="T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6b" >
# <thead>    <tr>
#         <th class="index_name level0" >Scheme</th>
#         <th class="col_heading level0 col0" >Mean</th>
#         <th class="col_heading level0 col1" colspan=3>Hillclimb</th>
#         <th class="col_heading level0 col4" colspan=3>Sigmoid</th>
#         <th class="col_heading level0 col7" colspan=3>Exp</th>
#         <th class="col_heading level0 col10" colspan=3>Expvar</th>
#         <th class="col_heading level0 col13" colspan=3>Binary</th>
#         <th class="col_heading level0 col16" colspan=3>Linear</th>
#     </tr>    <tr>
#         <th class="index_name level1" >MarkovLength</th>
#         <th class="col_heading level1 col0" ></th>
#         <th class="col_heading level1 col1" >1</th>
#         <th class="col_heading level1 col2" >10</th>
#         <th class="col_heading level1 col3" >100</th>
#         <th class="col_heading level1 col4" >1</th>
#         <th class="col_heading level1 col5" >10</th>
#         <th class="col_heading level1 col6" >100</th>
#         <th class="col_heading level1 col7" >1</th>
#         <th class="col_heading level1 col8" >10</th>
#         <th class="col_heading level1 col9" >100</th>
#         <th class="col_heading level1 col10" >1</th>
#         <th class="col_heading level1 col11" >10</th>
#         <th class="col_heading level1 col12" >100</th>
#         <th class="col_heading level1 col13" >1</th>
#         <th class="col_heading level1 col14" >10</th>
#         <th class="col_heading level1 col15" >100</th>
#         <th class="col_heading level1 col16" >1</th>
#         <th class="col_heading level1 col17" >10</th>
#         <th class="col_heading level1 col18" >100</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6blevel0_row0" class="row_heading level0 row0" >11</th>
#         <td id="T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow0_col0" class="data row0 col0" >58.083</td>
#         <td id="T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow0_col1" class="data row0 col1" >-5.584</td>
#         <td id="T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow0_col2" class="data row0 col2" >-5.584</td>
#         <td id="T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow0_col3" class="data row0 col3" >-5.584</td>
#         <td id="T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow0_col4" class="data row0 col4" >-3.172</td>
#         <td id="T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow0_col5" class="data row0 col5" >-1.74</td>
#         <td id="T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow0_col6" class="data row0 col6" >5.045</td>
#         <td id="T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow0_col7" class="data row0 col7" >-3.751</td>
#         <td id="T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow0_col8" class="data row0 col8" >-4.317</td>
#         <td id="T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow0_col9" class="data row0 col9" >5.045</td>
#         <td id="T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow0_col10" class="data row0 col10" >-0.39</td>
#         <td id="T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow0_col11" class="data row0 col11" >1.496</td>
#         <td id="T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow0_col12" class="data row0 col12" >5.045</td>
#         <td id="T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow0_col13" class="data row0 col13" >-0.709</td>
#         <td id="T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow0_col14" class="data row0 col14" >-0.709</td>
#         <td id="T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow0_col15" class="data row0 col15" >5.045</td>
#         <td id="T_ab9c271e_fe10_11e8_ad0f_2816ad4d1b6brow0_col16" class="data row0 col16" >

# %%
a = [[1,2,3],[4,5,6],[7,8,9]]
print(a)
a.insert(0,0)
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]

# %%
import seaborn as sns

cm = sns.light_palette("green", as_cmap=True)

s = p.round(4).T.style.background_gradient(cmap=cm)
s
# Out:
# <style  type="text/css" >
#     #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow0_col0 {
#             background-color:  #e5ffe5;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow0_col1 {
#             background-color:  #0f880f;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow0_col2 {
#             background-color:  #0f880f;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow0_col3 {
#             background-color:  #0f880f;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow0_col4 {
#             background-color:  #49a849;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow0_col5 {
#             background-color:  #49a849;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow0_col6 {
#             background-color:  #8fcf8f;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow0_col7 {
#             background-color:  #49a849;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow0_col8 {
#             background-color:  #49a849;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow0_col9 {
#             background-color:  #8fcf8f;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow0_col10 {
#             background-color:  #a3daa3;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow0_col11 {
#             background-color:  #c4edc4;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow0_col12 {
#             background-color:  #7dc57d;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow0_col13 {
#             background-color:  #8fcf8f;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow0_col14 {
#             background-color:  #cff3cf;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow0_col15 {
#             background-color:  #8fcf8f;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow0_col16 {
#             background-color:  #7cc57c;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow0_col17 {
#             background-color:  #9ed89e;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow0_col18 {
#             background-color:  #bde9bd;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow1_col0 {
#             background-color:  #e0fce0;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow1_col1 {
#             background-color:  #61b661;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow1_col2 {
#             background-color:  #61b661;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow1_col3 {
#             background-color:  #61b661;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow1_col4 {
#             background-color:  #158b15;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow1_col5 {
#             background-color:  #158b15;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow1_col6 {
#             background-color:  #339c33;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow1_col7 {
#             background-color:  #abdfab;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow1_col8 {
#             background-color:  #158b15;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow1_col9 {
#             background-color:  #339c33;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow1_col10 {
#             background-color:  #3aa03a;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow1_col11 {
#             background-color:  #8fcf8f;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow1_col12 {
#             background-color:  #9ed89e;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow1_col13 {
#             background-color:  #339c33;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow1_col14 {
#             background-color:  #abdfab;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow1_col15 {
#             background-color:  #339c33;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow1_col16 {
#             background-color:  #9ed79e;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow1_col17 {
#             background-color:  #b5e4b5;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow1_col18 {
#             background-color:  #d1f4d1;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow2_col0 {
#             background-color:  #d7f7d7;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow2_col1 {
#             background-color:  #94d294;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow2_col2 {
#             background-color:  #94d294;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow2_col3 {
#             background-color:  #94d294;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow2_col4 {
#             background-color:  #e5ffe5;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow2_col5 {
#             background-color:  #e5ffe5;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow2_col6 {
#             background-color:  #0b860b;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow2_col7 {
#             background-color:  #e5ffe5;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow2_col8 {
#             background-color:  #e5ffe5;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow2_col9 {
#             background-color:  #0b860b;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow2_col10 {
#             background-color:  #0d870d;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow2_col11 {
#             background-color:  #008000;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow2_col12 {
#             background-color:  #068306;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow2_col13 {
#             background-color:  #0b860b;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow2_col14 {
#             background-color:  #9cd69c;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow2_col15 {
#             background-color:  #0b860b;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow2_col16 {
#             background-color:  #068306;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow2_col17 {
#             background-color:  #4eab4e;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow2_col18 {
#             background-color:  #62b662;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow3_col0 {
#             background-color:  #d1f4d1;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow3_col1 {
#             background-color:  #2a972a;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow3_col2 {
#             background-color:  #2a972a;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow3_col3 {
#             background-color:  #2a972a;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow3_col4 {
#             background-color:  #69ba69;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow3_col5 {
#             background-color:  #69ba69;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow3_col6 {
#             background-color:  #caf0ca;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow3_col7 {
#             background-color:  #69ba69;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow3_col8 {
#             background-color:  #69ba69;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow3_col9 {
#             background-color:  #caf0ca;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow3_col10 {
#             background-color:  #e5ffe5;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow3_col11 {
#             background-color:  #e5ffe5;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow3_col12 {
#             background-color:  #008000;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow3_col13 {
#             background-color:  #caf0ca;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow3_col14 {
#             background-color:  #e5ffe5;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow3_col15 {
#             background-color:  #caf0ca;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow3_col16 {
#             background-color:  #008000;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow3_col17 {
#             background-color:  #4aa94a;
#         }    #T_63d0145c_fd8f_11e8_b75b_2816ad4d1b6brow3_col18 {
#             background-color:  #72bf72;
#         }    #T_63d0145c_fd8f_11e8_b75b_281

# %%
schemas = []
mcls = []
data = np.random.randn(len(index),4)
for i, scheme in enumerate(schemes):
    for ml in mcl:
        schemas.append(scheme)
        mcls.append(ml)
arrays = [schemas,mcls]
tuples = list(zip(*arrays))
index = pd.MultiIndex.from_tuples(tuples, names=['Scheme', 'MarkovLength'])
print(data)
s = pd.DataFrame(data, index=index, columns=list(range(11, 11 + len(data[0]))))
s

# %%
# list(range(11, 11 + len(arrays)))
arrays

# %%
def plot(coordList):
    plt.rcParams['figure.figsize'] = [10, 10]
    sns.set()
    sns.set_style("white")
    fig = plt.figure()
    ax = plt.subplot(111)
    colors = list(range(len(coordList)))
    ax.scatter(coordList[:, 0], coordList[:, 1], c=colors, cmap='Dark2')
    circle1 = plt.Circle((0, 0), radius, alpha=0.2, color="olive")
    ax.add_artist(circle1)
    plotpretify(
        ax,
        1.1,
        minx=-1.1,
        miny=-1.1,
        maxy=1.1,
        Grid=False,
        LL=False,
        LB=False)

# %%
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
from IPython.display import display

for j in range(len(coordListListList)):
    print(schemes[j])
    def showPlot(i=0):
        plot(coordListListList[j][i])

for cll in coordListListList:
    y = interactive(showPlot, i=(0, len(coordListListList[j]) - 1, 1))
#     y = interactive(showPlot, i=range(len(coordListListList[j])))
#     plot(coordListListList[j][-1])
    display(y)
